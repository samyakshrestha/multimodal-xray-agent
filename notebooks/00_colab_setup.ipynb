# %% [markdown]
# # 00_colab_setup.ipynb
#
# This notebook sets up the Colab environment by:
# - Mounting Google Drive
# - Navigating to the project root
# - Cloning the GitHub repo (if not already present)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/samyakshrestha/multimodal-xray-agent.git
# Out:
# Cloning into 'multimodal-xray-agent'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 16 (delta 3), reused 11 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (16/16), 8.05 KiB | 1.01 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
# !ls multimodal-xray-agent
# Out:
# app   deployment  models     PROJECT_LOG.md  requirements.txt  src
# data  LICENSE	  notebooks  README.md	     scripts
